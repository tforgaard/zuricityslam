# %%
import networkx as nx

from pathlib import Path

from cityslam.utils.parsers import find_models
from cityslam.graph.utils import find_graphs, get_graphs, draw_super, draw_graphs, transform_models

# %%
# Setup the paths
base_dir = Path('/cluster/project/infk/courses/252-0579-00L/group07')

models = base_dir / 'outputs' / 'models-features'
graphs = base_dir / 'outputs' / 'merge'
outputs = base_dir / 'outputs' / 'graph'

outputs.mkdir(exist_ok=True, parents=True)

# %%
model_folders = find_models(models)

super_graph = find_graphs(models, graphs)
maps = get_graphs(super_graph)

print(len(super_graph.nodes))
print(super_graph.nodes)
# Out:
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# no transform
# 69
# ['ITntTt4qkWY__part3', 'ITntTt4qkWY__part4', 'ITntTt4qkWY__part1', 'ITntTt4qkWY__part2', 'DdxEr70jC6E__part3__models__0', 'DdxEr70jC6E__part4__models__1', 'DdxEr70jC6E__part5__models__1', 'DdxEr70jC6E__part6__models__0', 'DdxEr70jC6E__part7__models__0', 'Ka3Ss3cdk0Y__part2', 'Ka3Ss3cdk0Y__part3', 'Ka3Ss3cdk0Y__part3__Ka3Ss3cdk0Y', 'part4__models__0', 'part4__models__2', 'part4__models__3', 'Ka3Ss3cdk0Y__part4__models__0', 'Ka3Ss3cdk0Y__part5', 'Ka3Ss3cdk0Y__part4__models__2', 'Ka3Ss3cdk0Y__part4__models__3', 'Ka3Ss3cdk0Y__part5__Ka3Ss3cdk0Y', 'part6__models__0', 'part6__models__2', 'Ka3Ss3cdk0Y__part6__models__0', 'Ka3Ss3cdk0Y__part7', 'Ka3Ss3cdk0Y__part6__models__2', '73IVzh0R-Lo__part0__models__1', '73IVzh0R-Lo__part1', '73IVzh0R-Lo__part0__models__2', '73IVzh0R-Lo__part2', '73IVzh0R-Lo__part2__73IVzh0R-Lo', 'part3__models__0', '73IVzh0R-Lo__part3__models__0', '73IVzh0R-Lo__part4', '73IVzh0R-Lo__part5', '73IVzh0R-Lo__part6', '73IVzh0R-Lo__part7', '2obsKLoZQdU__part00__models__0', '2obsKLoZQdU__part01', '2obsKLoZQdU__part00__models__1', '2obsKLoZQdU__part02', '2obsKLoZQdU__part03', '2obsKLoZQdU__part04', '2obsKLoZQdU__part05', '2obsKLoZQdU__part06', '2obsKLoZQdU__part07', '2obsKLoZQdU__part07__2obsKLoZQdU', 'part08__models__1', 'part08__models__2', '2obsKLoZQdU__part08__models__1', '2obsKLoZQdU__part09', '2obsKLoZQdU__part08__models__2', '2obsKLoZQdU__part10', '2obsKLoZQdU__part11', '2obsKLoZQdU__part11__2obsKLoZQdU', 'part12__models__1', '2obsKLoZQdU__part12__models__1', '2obsKLoZQdU__part13', '2obsKLoZQdU__part13__2obsKLoZQdU', 'part14__models__0', '2obsKLoZQdU__part14__models__0', '2obsKLoZQdU__part15', '_NmYvuEILw4__part0__models__0', '_NmYvuEILw4__part1__models__0', '_NmYvuEILw4__part0__models__1', '_NmYvuEILw4__part2', '_NmYvuEILw4__part10__models__1', '_NmYvuEILw4__part11__models__0', '_NmYvuEILw4__part12__models__1', '_NmYvuEILw4__part3']

# %%
base_node = '2obsKLoZQdU__part06'
super_graph.nodes[base_node]
# Out:
# {'model': PosixPath('2obsKLoZQdU/part06')}

# %%
draw_super(super_graph, models)

draw_graphs(maps)

# %%
transform_models(models, outputs, maps[0], visualize=False, save=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8162/2715795293.py in <module>
# ----> 1 transform_models(models, outputs, maps[0], visualize=False, save=True)
#
# ~/Projects/zuricityslam/cityslam/graph/utils.py in transform_models(models, outputs, graph, base_node, visualize, save)
#      86
#      87         b.export_PLY(outputs / "ply" / f"{base_node}.ply")
# ---> 88         b.write(outputs / "models" / base_node)
#      89
#      90
#
# ValueError: [reconstruction.cc:104] Check Failed: ExistsDir(path) : Directory /cluster/project/infk/courses/252-0579-00L/group07/outputs/graph/2obsKLoZQdU__part01/models/2obsKLoZQdU__part01 does not exist.
